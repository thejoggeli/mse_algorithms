# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from MyBinaryTree import BinaryTree, BinaryTreeNode

# %%
values = [
    60, 
    50, 70, 
    40, 55, 65, 80, 
    30, 45, 53, 58, 63, 68, 75, 90,
    20, 35, 42
]

tree = BinaryTree()
tree.build(values)

print("depth:", tree.depth)
print("minimum:", tree.minimum())
print("find:", tree.find(55))

tree.draw()

tree.delete(tree.find(60))

tree.draw()

tree.insert(60)

tree.draw()
# Out:
# depth: 5
# minimum: idx=16, depth=5, val=20
# find: idx=4, depth=3, val=55
