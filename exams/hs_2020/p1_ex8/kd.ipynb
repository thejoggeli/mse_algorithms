# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from MyKDTree import KDTree

# %%
tree = KDTree()

tree.add_point(1, 3)
tree.add_point(12, 1)
tree.add_point(4, 5)
tree.add_point(5, 4)
tree.add_point(10, 11)
tree.add_point(8, 2)
tree.add_point(2, 7)

# build the tree
tree.build(split_between=True)

# print three
tree.print()

# draw split
matplotlib.rcParams['figure.figsize'] = [10, 5]
tree.draw_split()

# draw tree
matplotlib.rcParams['figure.figsize'] = [11, 5]
tree.draw_tree()
# Out:
# depth=1, L=6.5
# depth=2, L=4.5
# depth=3, L=3.0
# depth=4, P=Point(index=0, number=1, x=1, y=3)
# depth=4, P=Point(index=3, number=4, x=5, y=4)
# depth=3, L=3.0
# depth=4, P=Point(index=6, number=7, x=2, y=7)
# depth=4, P=Point(index=2, number=3, x=4, y=5)
# depth=2, L=6.5
# depth=3, L=10.0
# depth=4, P=Point(index=5, number=6, x=8, y=2)
# depth=4, P=Point(index=1, number=2, x=12, y=1)
# depth=3, P=Point(index=4, number=5, x=10, y=11)
